# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

HEADERS = {'User-Agent': '', 'Accept-Language': 'en-US, en;q=0.5'}

def fetch_text_from_element(soup, target_tag, attributes):
    try:
        found_element = soup.find(target_tag, attrs=attributes).string.strip()
    except AttributeError:
        found_element = ""
    return found_element

def fetch_review_count(soup):
    return fetch_text_from_element(soup, "span", {'id': 'acrCustomerReviewText'})

def extract_product_title(soup):
    try:
        title_element = soup.find("span", attrs={"id": 'productTitle'})
        title_value = title_element.text
        formatted_title = title_value.strip()
    except AttributeError as e:
        formatted_title = f"Error: {e}"
    return formatted_title

def extract_product_rating(soup):
    return fetch_text_from_element(soup, "i", {'class': 'a-icon a-icon-star a-star-4-5'}) or fetch_text_from_element(soup, "span", {'class': 'a-icon-alt'})

def check_product_availability(soup):
    try:
        availability_info = soup.find("div", attrs={'id': 'availability'})
        availability_text = availability_info.find("span").string.strip()
    except AttributeError:
        availability_text = "Not Available"
    return availability_text

def extract_product_price(soup):
    price_element = soup.find("span", attrs={"class": "a-price-whole"})
    if price_element:
        price_value = price_element.text
        return price_value
    else:
        return None

if __name__ == '__main__':
    URL = 'https://www.amazon.in/s?i=shoes&bbn=1983518031&rh=n%3A1983518031%2Cp_n_feature_nineteen_browse-bin%3A11301363031%2Cp_89%3APuma&s=shoes&dc&ds=v1%3AOeRhZn4pD6sD9gk%2FOVfSDnmfUL8aTssLDqnY4pL2Kok&pf_rd_i=1983518031&pf_rd_i=1983518031&pf_rd_m=A1VBAL9TL5WCBF&pf_rd_m=A1VBAL9TL5WCBF&pf_rd_p=0a2cc271-509d-4e6c-a55b-f2a271405749&pf_rd_p=f1226c7e-2394-47e8-8298-4069f238c983&pf_rd_r=2FVEK59QSAWC35YANQ00&pf_rd_r=HCWGHCYG4V99QN6YJZBM&pf_rd_s=merchandised-search-6&pf_rd_s=merchandised-search-6&qid=1681034803&rnid=3837712031&ref=sr_nr_p_89_12'
    webpage = requests.get(URL, headers=HEADERS)
    soup = BeautifulSoup(webpage.content, "html.parser")

    links = soup.find_all("a", attrs={'class': 'a-link-normal s-no-outline'})
    links_list = [link.get('href') for link in links]

    data_list = []

    for link in links_list:
        new_webpage = requests.get("https://www.amazon.in" + link, headers=HEADERS)
        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        data_list.append({
            'title': extract_product_title(new_soup),
            'price': extract_product_price(new_soup),
            'rating': extract_product_rating(new_soup),
            'reviews': fetch_review_count(new_soup),
            'availability': check_product_availability(new_soup)
        })

    df = pd.DataFrame(data_list)

# %%
df
# Out:
#                                                 title   price  \
# 0                         Puma Men's Dazzler Sneakers   1,483
# 1                         Puma Unisex-Adult Slide Max     858
# 2                Puma Unisex-Adult SmashicCasual Shoe    999.
# 3                         Puma Unisex-Adult Geo Slide     858
# 4                        Puma Mens CoarseRunning Shoe   1,519
# 5                Puma Mens Ultimate Ease Walking Shoe   1,609
# 6          Puma Unisex-Adult Wired Rapid Running Shoe   2,199
# 7                         Puma mens Snatch V2 Sneaker   1,551
# 8                        Puma mens Atlas Walking Shoe   2,429
# 9                             Puma Mens Running Shoes   1,639
# 10  Puma Unisex-Adult Popcat 20 Shower Res Slide S...     889
# 11      Puma unisex-adult Disperse Xt 2 Training Shoe   2,099
# 12              Puma Unisex-Adult Robust Running Shoe   1,509
# 13             Puma Unisex-Adult Purecat Slide Sandal     989
# 14        Puma Unisex-Adult Divecat V2 Lite Cat Slide     869
# 15  PUMA Unisex Adult Trigger Black White-Quarry R...   1,879
# 16  Puma Unisex-Adult Ferrari Future Cat Ultra Sho...   2,799
# 17    Puma Unisex-Adult Comet 2 Alt Beta Running Shoe   2,169
# 18                Puma Unisex-Adult Duke Running Shoe   1,689
# 19         Puma Womens Wired Imeva Shoes Running Shoe   1,710
# 20            Puma Mens Zod Runner Nm Idp Closed Shoe  1,294.
# 21                         Puma mens Caper Nu Slipper     833
# 22                  Puma Mens Emergence Running Shoes   2,089
# 23  Puma Mens Maximal Comfort-everglide Range Walk...   1,609
# 24              Puma Unisex-Adult Flair 2Running Shoe   2,311
# 25                      Puma Mens AlfarunRunning Shoe  1,587.
# 26                    Puma unisex-adult Disperse Xt 2  1,872.
# 27        Puma Unisex-Adult Galaxy Comfort V3 Slipper     999
# 28                        PUMA Men's Hexa IDP Sandals   1,426
# 29             Puma Mens Dexster Slip on Walking Shoe   1,454
# 30           Puma Mens Cricket Classicat Cricket Shoe   2,189
# 31                Puma Mens Turf Slip on Walking Shoe   1,799
# 32                        Puma Mens Zeta Running Shoe   2,469
# 33         Puma Mens Cell Fraction Mesh Training Shoe   3,165
# 34  Puma Unisex-Adult Ferrari Drift Cat Delta Sneaker   2,799
# 35   Puma Unisex-Adult Rebound Future Evo Casual Shoe   2,099
# 36   Puma Unisex-Adult Royalcat Comfort Sandals Slide   2,239
# 37                            Puma Mens Draco Sneaker   2,346
# 38   Puma Unisex-Adult Softride Cruise 2 Walking Shoe   2,453
# 39           Puma Unisex-Adult Triumph X V6 Flip-Flop     369
# 40                    Puma Mens Seawalk Running Shoes   1,520
# 41                           Puma Men's Brizo Slipper     449
# 42       Puma Unisex-Adult Popcat 20 Res Slide Sandal     890
# 43  Puma Unisex-Adult Softride Rift Knit One8 Walk...   2,786
# 44            Puma Unisex-Adult Wave Flip Res Slipper     709
# 45  Puma Unisex-Adult Dare Black-White Sneaker - 7...   2,019
# 46             Puma Unisex-Adult Aviator Running Shoe   3,199
# 47             Puma unisex-adult Anzarun Lite Sneaker   1,749
#
#                 rating         reviews           availability
# 0   4.0 out of 5 stars   4,914 ratings               In stock
# 1   4.0 out of 5 stars     939 ratings               In stock
# 2   3.9 out of 5 stars     593 ratings          Not Available
# 3   4.0 out of 5 stars   1,329 ratings               In stock
# 4   3.9 out of 5 stars     392 ratings               In stock
# 5   4.0 out of 5 stars   3,203 ratings               In stock
# 6   3.9 out of 5 stars     211 ratings               In stock
# 7   4.0 out of 5 stars   2,818 ratings               In stock
# 8   3.8 out of 5 stars   1,065 ratings               In stock
# 9   4.0 out of 5 stars     206 ratings               In stock
# 10  3.9 out of 5 stars     112 ratings               In stock
# 11  4.1 out of 5 stars     272 ratings               In stock
# 12  4.0 out of 5 stars   1,419 ratings               In stock
# 13  3.8 out of 5 stars  28,959 ratings               In stock
# 14  4.0 out of 5 stars      79 ratings               In stock
# 15  4.0 out of 5 stars   1,476 ratings               In stock
# 16  4.1 out of 5 stars     184 ratings               In stock
# 17  3.9 out of 5 stars     715 ratings               In stock
# 18  4.0 out of 5 stars     662 ratings               In stock
# 19  4.0 out of 5 stars     322 ratings               In stock
# 20  3.9 out of 5 stars   1,213 ratings               In stock
# 21  4.0 out of 5 stars     747 ratings               In stock
# 22  4.1 out of 5 stars     797 ratings               In stock
# 23  4.0 out of 5 stars   2,694 ratings               In stock
# 24  3.9 out of 5 stars     223 ratings               In stock
# 25  3.9 out of 5 stars      90 ratings               In stock
# 26  4.2 out of 5 stars      25 ratings               In stock
# 27  3.6 out of 5 stars     267 ratings               In stock
# 28  4.0 out of 5 stars     316 ratings               In stock
# 29  3.8 out of 5 stars     510 ratings               In stock
# 30  4.1 out of 5 stars      84 ratings               In stock
# 31  3.7 out of 5 stars      71 ratings               In stock
# 32  4.2 out of 5 stars     675 ratings  Only 3 left in stock.
# 33  4.1 out of 5 stars     187 ratings               In stock
# 34  3.8 out of 5 stars     428 ratings               In stock
# 35  4.2 out of 5 stars     479 ratings               In stock
# 36  4.1 out of 5 stars   3,124 ratings               In stock
# 37  4.0 out of 5 stars   2,899 ratings               In stock
# 38  4.2 out of 5 stars      44 ratings  Only 3 left in stock.
# 39  3.8 out of 5 stars     169 ratings               In stock
# 40  4.1 out of 5 stars   4,383 ratings               In stock
# 41  4.0 out of 5 stars     114 ratings               In stock
# 42  4.0 out of 5 stars     493 ratings  Only 3 left in stock.
# 43  4.0 out of 5 stars      28 ratings               In stock
# 44  3.7 out of 5 stars     458 ratings               In stock
# 45  4.1 out of 5 stars     187 ratings               In stock
# 46  4.2 out of 5 stars     174 ratings               In stock
# 47  4.4 out of 5 stars     715 ratings               In stock
